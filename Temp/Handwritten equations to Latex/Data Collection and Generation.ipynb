# %%
import kaggle
import numpy as np
from PIL import Image
import imageio
import matplotlib.pyplot as plt
from scipy import ndimage
import tensorflow as tf
import math
import os
import json
import cv2

# %%
# download specified dataset
# !kaggle datasets download -d xainano/handwrittenmathsymbols --unzip
# Out:
# ...
#   0%|          | 0.00/343M [00:00<?, ?B/s]
#   0%|          | 1.00M/343M [00:00<00:37, 9.58MB/s]
#   1%|          | 3.00M/343M [00:00<00:35, 9.95MB/s]
#   1%|1         | 4.00M/343M [00:00<00:36, 9.78MB/s]
#   2%|1         | 6.00M/343M [00:00<00:33, 10.5MB/s]
#   2%|2         | 8.00M/343M [00:00<00:30, 11.4MB/s]
#   3%|2         | 10.0M/343M [00:00<00:28, 12.2MB/s]
#   4%|3         | 12.0M/343M [00:01<00:29, 12.0MB/s]
#   4%|4         | 14.0M/343M [00:01<00:27, 12.3MB/s]
#   5%|4         | 16.0M/343M [00:01<00:26, 13.1MB/s]
#   5%|5         | 18.0M/343M [00:01<00:25, 13.1MB/s]
#   6%|5         | 20.0M/343M [00:01<00:25, 13.4MB/s]
#   6%|6         | 22.0M/343M [00:01<00:24, 13.5MB/s]
#   7%|7         | 24.0M/343M [00:01<00:23, 14.0MB/s]
#   8%|7         | 26.0M/343M [00:02<00:25, 13.2MB/s]
#   8%|8         | 28.0M/343M [00:02<00:23, 14.0MB/s]
#   9%|8         | 30.0M/343M [00:02<00:23, 14.2MB/s]
#   9%|9         | 32.0M/343M [00:02<00:22, 14.3MB/s]
# ...
